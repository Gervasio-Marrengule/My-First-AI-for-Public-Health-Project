# %% [markdown]
# <a href="https://colab.research.google.com/github/Gervasio-Marrengule/My-First-AI-for-Public-Health-Project/blob/main/Into_python03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PROGRAMA INTERNACIONAL INTELIGÊNCIA ARTIFICIAL E BIG DATA APLICADOS À SAÚDE PÚBLICA E VIGILÂNCIA EPIDEMIOLÓGICA

# %% [markdown]
# AULA3 - VARIÁVEIS EM PYTHON

# %% [markdown]
# 1. Variáveis

# %%
# Variaveis são como "caixinhas" que guardam informações
# Exemplo 1:
# Utilização print()
casos_malaria = 197459
print(casos_malaria)
# Out:
# 197459

# %%
casos_malaria
# Out:
# 197459

# %%
#Exemplo 2:
# Sem utilizar print()
taxa_vacinação = 85,7
taxa_vacinação
# Out:
# (85, 7)

# %%
#Exemplo 2.1:
# Sem utilizar print()
taxa_de_positividade=50
taxa_de_positividade
# Out:
# 50

# %%
# Exemplo 3:
# Variável textual
provincia="Inhambane"
provincia
# Out:
# 'Inhambane'

# %% [markdown]
# 2. Variáveis com diferentes informações epidemiologicas

# %%
# Exemplo 1:
doença="malária"
casos=197459
taxa_de_positividade=50
print(doença)
print(casos)
print(taxa_de_positividade)
# Out:
# malária
# 197459
# 50

# %%
# Exemplo 2:
hospital="Hospital Provincial de Inhambane"
pacientes=5656
obitos=47
print(hospital)
print(pacientes)
print(obitos)
# Out:
# Hospital Provincial de Inhambane
# 5656
# 47

# %%
# Exemplo 3:
distrito= "Homoine"
testes_realizados=26055
positivos=13740
print(distrito)
print(testes_realizados)
print(positivos)
# Out:
# Homoine
# 26055
# 13740

# %% [markdown]
# 3. Declaração múltipla

# %%
# Exemplo 1:
casos, obitos=197459,4
print(casos)
print(obitos)
# Out:
# 197459
# 4

# %%
# Exemplo 2:
vacinados, não_vacinados = 2354, 381
print(vacinados)
print(não_vacinados)
# Out:
# 2354
# 381

# %%
vacinados
# Out:
# 2354

# %%
não_vacinados
# Out:
# 381

# %%
# Exemplo 3:
centros_saúdes, ambulâncias = 145, 11
print(centros_saúdes)
print(ambulâncias)
# Out:
# 145
# 11

# %% [markdown]
# 4. Pode-se usar letras, números e underline

# %%
# Exemplo 1:
casos_I_tirmestre2026=187459
casos_I_tirmestre2026
# Out:
# 187459

# %%
# Exemplo 2:
taxa_letalidade = 0,46
taxa_letalidade
# Out:
# (0, 46)

# %%
# Exemplo 2:
taxa_letalidade = 0,46
print(taxa_letalidade)
# Out:
# (0, 46)

# %%
# Exemplo 1:
região_norte = "Norte de Moçambique"
região_norte
# Out:
# 'Norte de Moçambique'

# %%
# Cont...
regiao_sul = "Sul de Moçambique"
regiao_sul
# Out:
# 'Sul de Moçambique'

# %% [markdown]
# 5. Variáveis atribuídas a outras variáveis

# %%
# Exemplo 1:
casos_semanal1 = 7365
casos_semanal2 = 12234
total = casos_semanal1 + casos_semanal2
print(total)
# Out:
# 19599

# %%
# Exemplo 2:
vacinados = 2354
população = 100000
taxa = vacinados/população * 100
taxa
# Out:
# 2.3539999999999996

# %%
# Exemplo 3:
testes = 26055
positivos = 13740
taxa_de_positividade = positivos/testes * 100
taxa_de_positividade
# Out:
# 52.73459988485896

# %%
# Exemplo 3:
testes = 26055
positivos = 13740
negativos = testes - positivos
print(negativos)
# Out:
# 12315

# %% [markdown]
# 6. Operações com variáveis

# %%
# Exemplo 1:
casos = 197459
obitos = 47
taxa_letalidade = obitos/casos * 100
taxa_letalidade
# Out:
# 0.023802409614147747

# %%
# Exemplo 2:
casos_distrito1 = 23454
casos_distrito2 = 32543
total_casos = casos_distrito1 + casos_distrito2
print(total_casos)
# Out:
# 55997

# %%
# Exemplo 3:
pacientes_por_dia = 3548
dias = 7
total_semana = pacientes_por_dia * dias
print(total_semana)
# Out:
# 24836

# %% [markdown]
# 7. Concatenação de Variáveis

# %%
# Exemplo 1:
provincia = "Zambézia"
casos = 370
print("A provincia de " + provincia + " registou " + str(casos) + " casos. ")
# Out:
# A provincia de Zambézia registou 370 casos.

# %%
# Exemplo 2:
doença = "malária"
taxa_de_positividade = 50
print("A taxa de positividade " + doença + " foi de " + str(taxa_de_positividade) + "%. ")
# Out:
# A taxa de positividade malária foi de 50%.

# %%
# Exemplo 3:
hospital = "Hospital Provincial de Inhambane"
pacientes = 656
print("O " + hospital + " atendeu " + str(pacientes) + " pacientes. ")
# Out:
# O Hospital Provincial de Inhambane atendeu 656 pacientes.
