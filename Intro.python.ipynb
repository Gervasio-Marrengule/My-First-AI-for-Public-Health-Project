# %% [markdown]
# <a href="https://colab.research.google.com/github/Gervasio-Marrengule/My-First-AI-for-Public-Health-Project/blob/main/Intro.python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Exemplo 1
# adição
2+3
# Out:
# 5

# %%
#Exemplo 2
# Multiplocação
7*6
# Out:
# 42

# %%
# Exemplo 3
#Crescimento hipoteticode casos (pontencia - usa-se dois asteriscos **)
5**2
# Out:
# 25

# %%
# Exemplo 4
# Distritbuição de testes rapidos (resto de uma divsao calcula-se usando a porcentagem - %)
22%5
# Out:
# 2

# %%
#Exemplo 5
#Distribuição de medicamentos
257%7
# Out:
# 5

# %%
#Exemplo 6
#Multiplicação
45*6
# Out:
# 270

# %%
#Exemplo 7
45*7%4
# Out:
# 3
